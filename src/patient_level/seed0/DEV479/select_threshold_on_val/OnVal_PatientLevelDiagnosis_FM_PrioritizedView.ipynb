# %%
import numpy as np
import pandas as pd
import pickle
import os
import json
from sklearn.metrics import confusion_matrix as sklearn_cm
from scipy.special import softmax
from scipy.stats import entropy

# %%
from collections import Counter

# %%
def load_json(directory, filename):
    with open(os.path.join(directory, filename), 'r') as f:
        
        data = json.load(f)
    
    return data

# %%
def load_pickle(result_dir, filename):
    with open(os.path.join(result_dir, filename), 'rb') as f:
        data = pickle.load(f)
    
    return data

# %%
def calculate_balanced_accuracy(true_labels, predicted_labels, return_type='balanced_accuracy'):
    '''
    used particularly for this 3-classes classification task
    '''
    
    confusion_matrix = sklearn_cm(true_labels, predicted_labels)
    
    class0_recall = confusion_matrix[0,0]/np.sum(confusion_matrix[0])
    class1_recall = confusion_matrix[1,1]/np.sum(confusion_matrix[1])
    class2_recall = confusion_matrix[2,2]/np.sum(confusion_matrix[2])
    
    balanced_accuracy = (1/3)*class0_recall + (1/3)*class1_recall + (1/3)*class2_recall
    
    if return_type == 'all':
        return balanced_accuracy * 100, class0_recall * 100, class1_recall * 100, class2_recall * 100
    elif return_type == 'balanced_accuracy':
        return balanced_accuracy * 100
    else:
        raise NameError('Unsupported return_type in this calculate_balanced_accuracy fn')

# %% [markdown]
# ### Get test patient study image grouping

# %%
StudyOrderInfo_dir = 'YOUR_PATH/ViewClassifier/seed0/DEV479/study_order_info'

study_order_list = load_json(StudyOrderInfo_dir, 'ForPatientTestSet_val_study_order_list.json')
studylevel_count_dicts = load_json(StudyOrderInfo_dir, 'ForPatientTestSet_val_study_level_count_dicts.json')

study_view_label_list = load_json(StudyOrderInfo_dir, 'ForPatientTestSet_val_study_view_label_list.json')
study_diagnosis_label_list = load_json(StudyOrderInfo_dir, 'ForPatientTestSet_val_study_diagnosis_label_list.json')

# %%
study_view_label_list
# Out:
# ['Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'A4C',
#  'A4C',
#  'A4C',
#  'A4C',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'A2C',
#  'A2C',
#  'A2C',
#  'A2C',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  ...]

# %%
study_diagnosis_label_list
# Out:
# ['no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  ...]

# %%
Simplified_study_order_list = []
for study in study_order_list:
    if study not in Simplified_study_order_list:
        Simplified_study_order_list.append(study)
        
Simplified_study_order_list
# Out:
# ['1867072',
#  '2955425',
#  '2513204',
#  '1169513',
#  '1176449',
#  '786898_s2',
#  '2039332',
#  '2471143',
#  '1177412_s2',
#  '2907071',
#  '2176623',
#  '2462129',
#  '851753',
#  '2696947',
#  '2496345',
#  '2897903',
#  '2947216',
#  '985472',
#  '2945392',
#  '2528258',
#  '2952565',
#  '2735520',
#  '790314',
#  '1996889',
#  '2960574',
#  '986661',
#  '11111941',
#  '3010285',
#  '2720361',
#  '905160',
#  '2509426',
#  '2827441',
#  '1860438',
#  '2912676',
#  '2968758',
#  '2894038',
#  '2170811',
#  '1321192',
#  '11091944',
#  '927215',
#  '1706176',
#  '1976168',
#  '2964822',
#  '2713001',
#  '2616799',
#  '709867',
#  '799891',
#  '1521872',
#  '2164053',
#  '2868730',
#  '2591537',
#  '2038999',
#  '2930582',
#  '2465467',
#  '1652478',
#  '1290316',
#  '2482656',
#  '2947108',
#  '2715436',
#  '1267792',
#  '1864080',
#  '2931325',
#  '3088064',
#  '1781590',
#  '2625905',
#  '855076',
#  '1496159',
#  '2817619',
#  '2322172',
#  '2569372',
#  '2576702',
#  '2525420',
#  '2967904',
#  '2927071',
#  '2375650',
#  '2592692',
#  '3083700',
#  '2915995',
#  '1483072',
#  '2539747',
#  '2937270',
#  '863452',
#  '2125141',
#  '2494490',
#  '2532640',
#  '2591761',
#  '2896093',
#  '2578670',
#  '1990857',
#  '1111207',
#  '1684463',
#  '1606929',
#  '2925008',
#  '2197390',
#  '1643556',
#  '2213600',
#  '2780612',
#  '1001302',
#  '2448176',
#  '1080000',
#  '2762160',
#  '3093091',
#  '2850632',
#  '1057994',
#  '1654260',
#  '2385950',
#  '2520510',
#  '2479348',
#  '701175',
#  '2630076',
#  '2588889',
#  '1804444',
#  '2930384',
#  '1881353',
#  '2628061',
#  '2361812',
#  '1462818',
#  '2934400',
#  '1102568']

# %%
num_studies = len(Simplified_study_order_list)
print('num_studies: {}'.format(num_studies))

Simplified_study_ImageCount_list = []
Simplified_study_DataIndicesRange_list = []

for study in Simplified_study_order_list:
    print('processing study: {}'.format(study))
    this_study_number_images = 0
    for diagnosis_label, counts in studylevel_count_dicts[study]['diagnosislabels_count'].items():
        print('diagnosis: {}, count: {}'.format(diagnosis_label, counts))
        this_study_number_images += counts
    
    
    assert this_study_number_images == Counter(study_order_list)[study]
        
    Simplified_study_ImageCount_list.append(this_study_number_images)
    print('\n')
    
Simplified_study_DataIndicesEndpoints_list = np.insert(np.cumsum(Simplified_study_ImageCount_list), 0, 0)
print('Simplified_study_DataIndicesEndpoints_list: {}'.format(Simplified_study_DataIndicesEndpoints_list))

for i in range(num_studies):
    Simplified_study_DataIndicesRange_list.append((Simplified_study_DataIndicesEndpoints_list[i], Simplified_study_DataIndicesEndpoints_list[i+1]))
        
print('Simplified_study_DataIndicesRange_list: {}'.format(Simplified_study_DataIndicesRange_list))
# Out:
# num_studies: 119
# processing study: 1867072
# diagnosis: no_AS, count: 46
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2955425
# diagnosis: no_AS, count: 83
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2513204
# diagnosis: no_AS, count: 52
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1169513
# diagnosis: no_AS, count: 90
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1176449
# diagnosis: no_AS, count: 70
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 786898_s2
# diagnosis: no_AS, count: 96
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2039332
# diagnosis: no_AS, count: 59
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2471143
# diagnosis: no_AS, count: 104
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1177412_s2
# diagnosis: no_AS, count: 62
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2907071
# diagnosis: no_AS, count: 111
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2176623
# diagnosis: no_AS, count: 60
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2462129
# diagnosis: no_AS, count: 58
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 851753
# diagnosis: no_AS, count: 66
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2696947
# diagnosis: no_AS, count: 59
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2496345
# diagnosis: no_AS, count: 59
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2897903
# diagnosis: no_AS, count: 74
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2947216
# diagnosis: no_AS, count: 79
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 985472
# diagnosis: no_AS, count: 101
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2945392
# diagnosis: no_AS, count: 89
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2528258
# diagnosis: no_AS, count: 99
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2952565
# diagnosis: no_AS, count: 69
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2735520
# diagnosis: no_AS, count: 38
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 790314
# diagnosis: no_AS, count: 67
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1996889
# diagnosis: no_AS, count: 82
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2960574
# diagnosis: no_AS, count: 58
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 986661
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 65
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 11111941
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 55
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 3010285
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 86
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2720361
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count:
#          '2616799': 64,
#          '709867': 66,
#          '799891': 62,
#          '1521872': 61,
#          '2164053': 90,
#          '2868730': 107,
#          '2591537': 77,
#          '2038999': 72,
#          '2930582': 103,
#          '2465467': 78,
#          '1652478': 54,
#          '1290316': 104,
#          '2482656': 81,
#          '2947108': 53,
#          '2715436': 62,
#          '1267792': 41,
#          '1864080': 59,
#          '2931325': 71,
#          '3088064': 102,
#          '1781590': 73,
#          '2625905': 78,
#          '855076': 75,
#          '1496159': 66,
#          '2817619': 65,
#          '2322172': 79,
#          '2569372': 66,
#          '2576702': 69,
#          '2525420': 77,
#          '2967904': 39,
#          '2927071': 73,
#          '2375650': 66,
#          '2592692': 61,
#          '3083700': 94,
#          '2915995': 58,
#          '1483072': 57,
#          '2539747': 54,
#          '2937270': 93,
#          '863452': 58,
#          '2125141': 73,
#          '2494490': 68,
#          '2532640': 59,
#          '2591761': 93,
#          '2896093': 81,
#          '2578670': 66,
#          '1990857': 69,
#          '1111207': 83,
#          '1684463': 115,
#          '1606929': 70,
#          '2925008': 61,
#          '2197390': 108,
#          '1643556': 57,
#          '2213600': 77,
#          '2780612': 84,
#          '1001302': 62,
#          '2448176': 83,
#          '1080000': 72,
#          '2762160': 28,
#          '3093091': 64,
#          '2850632': 58,
#          '1057994': 56,
#          '1654260': 59,
#          '2385950': 78,
#          '2520510': 41,
#          '2479348': 113,
#          '701175': 73,
#          '2630076': 75,
#          '2588889': 120,
#          '1804444': 99,
#          '2930384': 54,
#          '1881353': 61,
#          '2628061': 78,
#          '2361812': 64,
#          '1462818': 83,
#          '2934400': 108,
#          '1102568': 99})

# %% [markdown]
# ### Perform study level integration

# %% [markdown]
# ### FM + MU

# %%
candidate_view_dirs = [
      'PATH_TO_THE_MODEL'
]






candidate_diagnosis_dirs = [
    'PATH_TO_THE_MODEL/ForPatientTestSet_diagnosis_predictions/ema'
]

# %%
#View_predictions

# %%
#Diagnosis_predictions

# %%
np.linspace(0.1, 0.8, 71)
# Out:
# array([0.1 , 0.11, 0.12, 0.13, 0.14, 0.15, 0.16, 0.17, 0.18, 0.19, 0.2 ,
#        0.21, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.29, 0.3 , 0.31,
#        0.32, 0.33, 0.34, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4 , 0.41, 0.42,
#        0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.5 , 0.51, 0.52, 0.53,
#        0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63, 0.64,
#        0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71, 0.72, 0.73, 0.74, 0.75,
#        0.76, 0.77, 0.78, 0.79, 0.8 ])

# %%
confidence_threshold_list = np.linspace(0.8, 0.99, 20)

entropy_threshold_list = np.linspace(0, 1.6, 17)

combination_list = []
prioritizedview_performance_list = []
num_escape_study_list = []
escape_study_list = []

escape_study_viewpredictions_list = []
escape_study_diagnosispredictions_list = []
escape_study_diagnosistruelabels_list = []
escape_study_viewrelevance_list = []
escape_study_viewentropy_list = []

for confidence_threshold in confidence_threshold_list:
    print('########################Current confidence threshold: {}################'.format(confidence_threshold))
    
    for entropy_threshold in entropy_threshold_list:
        combination_list.append((confidence_threshold, entropy_threshold))
        
        print('Current entropy threshold: {}'.format(entropy_threshold))
        
        # candidate_view_dirs = [i for i in os.listdir(candidate_view_rootdir) if '.ipynb_checkpoints' not in i]

        for candidate_view in candidate_view_dirs:
        #     candidate_view = os.path.join(candidate_view_rootdir, candidate_view, 'best_predictions_at_ema_val')
            candidate_view = os.path.join(candidate_view, 'ForPatientTestSet_predictions')

#             if not os.path.exists(os.path.join(candidate_view, 'ForPatientTestSet_val_predictions.pkl')):
#                 continue
            View_predictions = load_pickle(candidate_view, 'ForPatientTestSet_val_predictions.pkl')

            for candidate_diagnosis in candidate_diagnosis_dirs:

                Diagnosis_predictions = load_pickle(candidate_diagnosis, 'val_predictions.pkl')

                #perform integration
                Diagnosis_true_labels = Diagnosis_predictions['true_labels']
                View_true_labels = View_predictions['true_labels']

                Diagnosis_predictions_values = Diagnosis_predictions['ema_predictions']
        #         Diagnosis_predictions_values = softmax(Diagnosis_predictions_values, axis=1)

                View_predictions_values = View_predictions['ema_predictions']
                View_predictions_values = softmax(View_predictions_values, axis=1)
                

                ConfidencedBased_PrioritizedView_predicted_labels = []
                ConfidencedBased_PrioritizedView_predictions = []

                study_true_diagnosis_labels = []

                escape_study_count = 0
                escape_studies = []
                
                escape_viewpredictions = []
                escape_diagnosispredictions = []
                escape_diagnosistruelabels = []
                escape_viewrelevance = []
                escape_viewentropy = []
                
                
                for idx, study in enumerate(Simplified_study_order_list):
        #             print('Currently aggregating predictions for {}'.format(study).center(100, '-'))
                    this_study_data_indices = list(range(Simplified_study_DataIndicesRange_list[idx][0], Simplified_study_DataIndicesRange_list[idx][1]))

                    this_study_diagnosis_predictions = Diagnosis_predictions_values[this_study_data_indices]
                    this_study_view_predictions = View_predictions_values[this_study_data_indices]
                    this_study_view_true_labels = View_true_labels[this_study_data_indices]

                    this_study_ViewRelevance =  np.sum(this_study_view_predictions[:,:2], axis=1)
                    this_study_ViewEntropy = entropy(this_study_view_predictions, axis=1)

                    #experiment with confidence level
                    confidence_mask = this_study_ViewRelevance >= confidence_threshold
                    
                    entropy_mask = this_study_ViewEntropy <= entropy_threshold
                    
                    final_mask = np.logical_and(confidence_mask, entropy_mask)
                    if np.sum(final_mask)<=0:
                        
                        escape_study_count+=1
                        escape_studies.append(study)
                        
                        this_study_diagnosis_true_labels = Diagnosis_true_labels[this_study_data_indices]
                        assert len(list(set(this_study_diagnosis_true_labels))) == 1, '1 study can only have 1 diagnosis label'
                        this_study_diagnosis_single_label = this_study_diagnosis_true_labels[0]
                        study_true_diagnosis_labels.append(this_study_diagnosis_single_label)

                        escape_viewpredictions.append(this_study_view_predictions)
                        escape_diagnosispredictions.append(this_study_diagnosis_predictions)
                        escape_diagnosistruelabels.append(this_study_diagnosis_single_label)
                        escape_viewrelevance.append(this_study_ViewRelevance)
                        escape_viewentropy.append(this_study_ViewEntropy)
                    

            #                 print('this_study_diagnosis_predictions: {}'.format(this_study_diagnosis_predictions.shape))
            #                 print('this_study_view_predictions: {}'.format(this_study_view_predictions.shape))

                        #Fall back to SimpleAveraging:
                        this_study_SimpleAveraging_prediction = np.mean(this_study_diagnosis_predictions, axis = 0) #a 1x3 vector
            #                 print('this_study_SimpleAveraging_prediction: {}'.format(this_study_SimpleAveraging_prediction))
                        this_study_SimpleAveraging_predicted_label = np.argmax(this_study_SimpleAveraging_prediction)
            #                 print('true_diagnosis:{}, SimpleAverage predicted_diagnosis:{}\n'.format(this_study_diagnosis_single_label, this_study_SimpleAveraging_predicted_label))

                        
                        #record this patient's ConfidenceBased_PrioritizedView predictions and predicted labels
                        ConfidencedBased_PrioritizedView_predictions.append(this_study_SimpleAveraging_prediction)
                        ConfidencedBased_PrioritizedView_predicted_labels.append(this_study_SimpleAveraging_predicted_label)
            #                 print('true_diagnosis:{}, ConfidenceBased_PrioritizedView predicted_diagnosis:{}\n'.format(this_study_diagnosis_single_label, this_study_DiagnosisPredictedLabel_with_ViewRelevance))

                        continue
                    
#                     print('num images above confidence level: {}'.format(np.sum(confidence_mask)))
#                     print('num images below entropy level: {}'.format(np.sum(entropy_mask)))


                    this_study_diagnosis_true_labels = Diagnosis_true_labels[this_study_data_indices]
                    assert len(list(set(this_study_diagnosis_true_labels))) == 1, '1 study can only have 1 diagnosis label'
                    this_study_diagnosis_single_label = this_study_diagnosis_true_labels[0]
                    study_true_diagnosis_labels.append(this_study_diagnosis_single_label)


                #     print('this_study_diagnosis_predictions * this_study_ViewRelevance[:, np.newaxis] shape:{}'.format((this_study_diagnosis_predictions * this_study_ViewRelevance[:, np.newaxis]).shape))
                    this_study_DiagnosisPrediction_with_ViewRelevance = this_study_diagnosis_predictions * this_study_ViewRelevance[:, np.newaxis]
                    this_study_DiagnosisPrediction_with_ViewRelevance = this_study_DiagnosisPrediction_with_ViewRelevance[final_mask]
                    this_study_DiagnosisPrediction_with_ViewRelevance = np.mean(this_study_DiagnosisPrediction_with_ViewRelevance, axis=0)
        #                 print('this_study_DiagnosisPrediction_with_ViewRelevance: {}'.format(this_study_DiagnosisPrediction_with_ViewRelevance))


                    this_study_DiagnosisPredictedLabel_with_ViewRelevance = np.argmax(this_study_DiagnosisPrediction_with_ViewRelevance)

                    #record this patient's ConfidenceBased_PrioritizedView predictions and predicted labels
                    ConfidencedBased_PrioritizedView_predictions.append(this_study_DiagnosisPrediction_with_ViewRelevance)
                    ConfidencedBased_PrioritizedView_predicted_labels.append(this_study_DiagnosisPredictedLabel_with_ViewRelevance)
        #                 print('true_diagnosis:{}, ConfidenceBased_PrioritizedView predicted_diagnosis:{}\n'.format(this_study_diagnosis_single_label, this_study_DiagnosisPredictedLabel_with_ViewRelevance))
                
                num_escape_study_list.append(escape_study_count)
                escape_study_list.append(escape_studies)
                
                escape_study_viewpredictions_list.append(escape_viewpredictions)
                escape_study_diagnosispredictions_list.append(escape_diagnosispredictions)
                escape_study_diagnosistruelabels_list.append(escape_diagnosistruelabels)
                escape_study_viewrelevance_list.append(escape_viewrelevance)
                escape_study_viewentropy_list.append(escape_viewentropy)
                
                ConfidencedBased_PrioritizedView_predictions = np.array(ConfidencedBased_PrioritizedView_predictions)

        #                 print('\n\n')
                ConfidenceBased_PrioritizedView_balanced_accuracy = calculate_balanced_accuracy(study_true_diagnosis_labels, ConfidencedBased_PrioritizedView_predicted_labels)
#                 print('view: {}, diagnosis: {}'.format(candidate_view, candidate_diagnosis))
                print('ConfidenceBased_PrioritizedView_balanced_accuracy: {}\n\n'.format(ConfidenceBased_PrioritizedView_balanced_accuracy))
                
                prioritizedview_performance_list.append(ConfidenceBased_PrioritizedView_balanced_accuracy)
                
        
               
combination_list = np.array(combination_list)
prioritizedview_performance_list = np.array(prioritizedview_performance_list)
num_escape_study_list = np.array(num_escape_study_list)
escape_study_list = np.array(escape_study_list)
escape_study_viewpredictions_list = np.array(escape_study_viewpredictions_list)
escape_study_diagnosispredictions_list = np.array(escape_study_diagnosispredictions_list)
escape_study_diagnosistruelabels_list = np.array(escape_study_diagnosistruelabels_list)
escape_study_viewrelevance_list = np.array(escape_study_viewrelevance_list)
escape_study_viewentropy_list = np.array(escape_study_viewentropy_list)
# Out:
# ########################Current confidence threshold: 0.8################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# ########################Current confidence threshold: 0.81################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.7124183006536
#
#
# ########################Current confidence threshold: 0.8200000000000001################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# ########################Current confidence threshold: 0.8300000000000001################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.15686274509804
#
#
# ########################Current confidence threshold: 0.8400000000000001################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.85################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.86################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.87################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.88################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.89################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.9################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.91################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.92################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.9299999999999999################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# ########################Current confidence threshold: 0.94################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# ########################Current confidence threshold: 0.95################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.02614379084966
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.601307189542474
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.045751633986924
#
#
# ########################Current confidence threshold: 0.96################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.7843137254902
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.359477124183
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# ########################Current confidence threshold: 0.97################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.45098039215686
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.7843137254902
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# ########################Current confidence threshold: 0.98################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.20915032679737
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 66.43137254901961
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.7843137254902
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.80392156862744
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.24836601307189
#
#
# ########################Current confidence threshold: 0.99################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 38.52941176470588
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.65359477124181
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.87581699346404
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.65359477124181
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.65359477124181
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.65359477124181
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.65359477124181
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.65359477124181
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.09803921568627
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.09803921568627
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.09803921568627
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.09803921568627
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.09803921568627
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.09803921568627
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.09803921568627
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.09803921568627
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.09803921568627
# <ipython-input-16-7177ba22d378>:162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_list = np.array(escape_study_list)
# <ipython-input-16-7177ba22d378>:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_viewpredictions_list = np.array(escape_study_viewpredictions_list)
# <ipython-input-16-7177ba22d378>:164: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_diagnosispredictions_list = np.array(escape_study_diagnosispredictions_list)
# <ipython-input-16-7177ba22d378>:165: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_diagnosistruelabels_list = np.array(escape_study_diagnosistruelabels_list)
# <ipython-input-16-7177ba22d378>:166: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_viewrelevance_list = np.array(escape_study_viewrelevance_list)
# <ipython-input-16-7177ba22d378>:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_viewentropy_list = np.array(escape_study_viewentropy_list)

# %%
np.argmax(prioritizedview_performance_list)
# Out:
# 308

# %%
##get all the occurance of the max value indices
max_all_indices = np.argwhere(prioritizedview_performance_list == np.max(prioritizedview_performance_list)).flatten().tolist()

# %%
max_all_indices
# Out:
# [308]

# %%
prioritizedview_performance_list[max_all_indices]
# Out:
# array([66.43137255])

# %%
num_escape_study_list[max_all_indices]
# Out:
# array([0])

# %%
escape_study_list[max_all_indices]
# Out:
# array([list([])], dtype=object)

# %%
combination_list[max_all_indices]
# Out:
# array([[0.98, 0.2 ]])
