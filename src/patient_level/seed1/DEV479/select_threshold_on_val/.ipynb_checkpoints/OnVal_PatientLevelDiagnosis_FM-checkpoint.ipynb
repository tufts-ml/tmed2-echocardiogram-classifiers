# %%
import numpy as np
import pandas as pd
import pickle
import os
import json
from sklearn.metrics import confusion_matrix as sklearn_cm
from scipy.special import softmax
from scipy.stats import entropy

# %%
from collections import Counter

# %%
def load_json(directory, filename):
    with open(os.path.join(directory, filename), 'r') as f:
        
        data = json.load(f)
    
    return data

# %%
def load_pickle(result_dir, filename):
    with open(os.path.join(result_dir, filename), 'rb') as f:
        data = pickle.load(f)
    
    return data

# %%
def calculate_balanced_accuracy(true_labels, predicted_labels, return_type='balanced_accuracy'):
    '''
    used particularly for this 3-classes classification task
    '''
    
    confusion_matrix = sklearn_cm(true_labels, predicted_labels)
    
    class0_recall = confusion_matrix[0,0]/np.sum(confusion_matrix[0])
    class1_recall = confusion_matrix[1,1]/np.sum(confusion_matrix[1])
    class2_recall = confusion_matrix[2,2]/np.sum(confusion_matrix[2])
    
    balanced_accuracy = (1/3)*class0_recall + (1/3)*class1_recall + (1/3)*class2_recall
    
    if return_type == 'all':
        return balanced_accuracy * 100, class0_recall * 100, class1_recall * 100, class2_recall * 100
    elif return_type == 'balanced_accuracy':
        return balanced_accuracy * 100
    else:
        raise NameError('Unsupported return_type in this calculate_balanced_accuracy fn')

# %% [markdown]
# ### Get test patient study image grouping

# %%
StudyOrderInfo_dir = 'YOUR_PATH/ML_DATA/ViewClassifier/seed1/DEV479/study_order_info'

study_order_list = load_json(StudyOrderInfo_dir, 'ForPatientTestSet_val_study_order_list.json')
studylevel_count_dicts = load_json(StudyOrderInfo_dir, 'ForPatientTestSet_val_study_level_count_dicts.json')

study_view_label_list = load_json(StudyOrderInfo_dir, 'ForPatientTestSet_val_study_view_label_list.json')
study_diagnosis_label_list = load_json(StudyOrderInfo_dir, 'ForPatientTestSet_val_study_diagnosis_label_list.json')

# %%
study_view_label_list
# Out:
# ['PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A4C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'A2C',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'PLAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'PLAX',
#  'PSAX',
#  'PSAX',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  'Useless_Unlabeled',
#  ...]

# %%
study_diagnosis_label_list
# Out:
# ['no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  'no_AS',
#  ...]

# %%
Simplified_study_order_list = []
for study in study_order_list:
    if study not in Simplified_study_order_list:
        Simplified_study_order_list.append(study)
        
Simplified_study_order_list
# Out:
# ['2962227',
#  '1597315',
#  '2454615',
#  '2939953',
#  '1762785',
#  '2501169',
#  '1996889',
#  '2860886',
#  '2949365',
#  '1712906',
#  '2844043',
#  '846980',
#  '2696947',
#  '2782589',
#  '1530039',
#  '1928248',
#  '2952565',
#  '2166150',
#  '2522079',
#  '1169513',
#  '2954377',
#  '2496345',
#  '2906335',
#  '2556651',
#  '2649221',
#  '976752',
#  '2482656',
#  '2715436',
#  '1372589',
#  '1756181',
#  '2937580',
#  '2616799',
#  '2720361',
#  '2600552',
#  '2964822',
#  '2534179',
#  '799891',
#  '1583600',
#  '2938563',
#  '2996591',
#  '2174843',
#  '1453747',
#  '11131934',
#  '1378284',
#  '2957580',
#  '2404527',
#  '2887476',
#  '2827441',
#  '2882883',
#  '2947108',
#  '2961909',
#  '2591537',
#  '7241941',
#  '870387',
#  '905160',
#  '1652478',
#  '2713001',
#  '2962243',
#  '2783608',
#  '1080000',
#  '1720159',
#  '2549009',
#  '2915617',
#  '2809073',
#  '2576702',
#  '2622325',
#  '1115099',
#  '1684463',
#  '2040590',
#  '1057994',
#  '2042804',
#  '2930384',
#  '1864080',
#  '1895549',
#  '1483072',
#  '2918929',
#  '3093091',
#  '2735098',
#  '2595013',
#  '2551434',
#  '2440548',
#  '1240962',
#  '2627034',
#  '1535525',
#  '2275375',
#  '3097712',
#  '2678681',
#  '2194907',
#  '3088064',
#  '1002530',
#  '2498445',
#  '2196796',
#  '1001302',
#  '2896498',
#  '2947660',
#  '2934400',
#  '2573324',
#  '1032034',
#  '2610924',
#  '2670788',
#  '2850632',
#  '2156543',
#  '2494490',
#  '2917861',
#  '2003267',
#  '1451504',
#  '2975679',
#  '2611449',
#  '2622451',
#  '2588818',
#  '2520169',
#  '1834284',
#  '2897940',
#  '2593005',
#  '2382238',
#  '2748486',
#  '2936416',
#  '2901426',
#  '901206']

# %%
num_studies = len(Simplified_study_order_list)
print('num_studies: {}'.format(num_studies))

Simplified_study_ImageCount_list = []
Simplified_study_DataIndicesRange_list = []

for study in Simplified_study_order_list:
    print('processing study: {}'.format(study))
    this_study_number_images = 0
    for diagnosis_label, counts in studylevel_count_dicts[study]['diagnosislabels_count'].items():
        print('diagnosis: {}, count: {}'.format(diagnosis_label, counts))
        this_study_number_images += counts
    
    
    assert this_study_number_images == Counter(study_order_list)[study]
        
    Simplified_study_ImageCount_list.append(this_study_number_images)
    print('\n')
    
Simplified_study_DataIndicesEndpoints_list = np.insert(np.cumsum(Simplified_study_ImageCount_list), 0, 0)
print('Simplified_study_DataIndicesEndpoints_list: {}'.format(Simplified_study_DataIndicesEndpoints_list))

for i in range(num_studies):
    Simplified_study_DataIndicesRange_list.append((Simplified_study_DataIndicesEndpoints_list[i], Simplified_study_DataIndicesEndpoints_list[i+1]))
        
print('Simplified_study_DataIndicesRange_list: {}'.format(Simplified_study_DataIndicesRange_list))
# Out:
# num_studies: 119
# processing study: 2962227
# diagnosis: no_AS, count: 68
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1597315
# diagnosis: no_AS, count: 71
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2454615
# diagnosis: no_AS, count: 54
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2939953
# diagnosis: no_AS, count: 85
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1762785
# diagnosis: no_AS, count: 86
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2501169
# diagnosis: no_AS, count: 68
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1996889
# diagnosis: no_AS, count: 82
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2860886
# diagnosis: no_AS, count: 96
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2949365
# diagnosis: no_AS, count: 102
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1712906
# diagnosis: no_AS, count: 82
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2844043
# diagnosis: no_AS, count: 61
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 846980
# diagnosis: no_AS, count: 65
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2696947
# diagnosis: no_AS, count: 59
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2782589
# diagnosis: no_AS, count: 92
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1530039
# diagnosis: no_AS, count: 59
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1928248
# diagnosis: no_AS, count: 81
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2952565
# diagnosis: no_AS, count: 69
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2166150
# diagnosis: no_AS, count: 65
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2522079
# diagnosis: no_AS, count: 64
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1169513
# diagnosis: no_AS, count: 90
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2954377
# diagnosis: no_AS, count: 64
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2496345
# diagnosis: no_AS, count: 59
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2906335
# diagnosis: no_AS, count: 72
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2556651
# diagnosis: no_AS, count: 109
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2649221
# diagnosis: no_AS, count: 63
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 976752
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 67
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2482656
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 81
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2715436
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 62
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1372589
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 46
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1756181
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 63
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2937580
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 37
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2616799
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 64
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2720361
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 87
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2600552
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 87
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2964822
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 0
# diagnosis: mildtomod_AS, count: 53
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2534179
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 91
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 799891
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 62
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 1583600
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count: 104
# diagnosis: mildtomod_AS, count: 0
# diagnosis: moderate_AS, count: 0
# diagnosis: severe_AS, count: 0
#
#
# processing study: 2938563
# diagnosis: no_AS, count: 0
# diagnosis: mild_AS, count:
#          '2915617': 74,
#          '2809073': 75,
#          '2576702': 69,
#          '2622325': 105,
#          '1115099': 82,
#          '1684463': 115,
#          '2040590': 74,
#          '1057994': 56,
#          '2042804': 63,
#          '2930384': 54,
#          '1864080': 59,
#          '1895549': 89,
#          '1483072': 57,
#          '2918929': 61,
#          '3093091': 64,
#          '2735098': 67,
#          '2595013': 76,
#          '2551434': 72,
#          '2440548': 60,
#          '1240962': 152,
#          '2627034': 84,
#          '1535525': 63,
#          '2275375': 62,
#          '3097712': 61,
#          '2678681': 93,
#          '2194907': 62,
#          '3088064': 102,
#          '1002530': 74,
#          '2498445': 49,
#          '2196796': 82,
#          '1001302': 62,
#          '2896498': 107,
#          '2947660': 71,
#          '2934400': 108,
#          '2573324': 22,
#          '1032034': 67,
#          '2610924': 61,
#          '2670788': 99,
#          '2850632': 58,
#          '2156543': 75,
#          '2494490': 68,
#          '2917861': 91,
#          '2003267': 84,
#          '1451504': 63,
#          '2975679': 66,
#          '2611449': 84,
#          '2622451': 95,
#          '2588818': 89,
#          '2520169': 64,
#          '1834284': 75,
#          '2897940': 36,
#          '2593005': 91,
#          '2382238': 143,
#          '2748486': 37,
#          '2936416': 171,
#          '2901426': 60,
#          '901206': 94})

# %% [markdown]
# ### Perform study level integration

# %% [markdown]
# ### FM + MU

# %%
candidate_view_dirs = [

        'PATH_TO_THE_MODEL'
]





candidate_diagnosis_dirs = [

    'PATH_TO_THE_MODEL/ForPatientTestSet_diagnosis_predictions/ema'
]

# %%
#View_predictions

# %%
#Diagnosis_predictions

# %%
np.linspace(0.1, 0.8, 71)
# Out:
# array([0.1 , 0.11, 0.12, 0.13, 0.14, 0.15, 0.16, 0.17, 0.18, 0.19, 0.2 ,
#        0.21, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.29, 0.3 , 0.31,
#        0.32, 0.33, 0.34, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4 , 0.41, 0.42,
#        0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.5 , 0.51, 0.52, 0.53,
#        0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63, 0.64,
#        0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71, 0.72, 0.73, 0.74, 0.75,
#        0.76, 0.77, 0.78, 0.79, 0.8 ])

# %%
confidence_threshold_list = np.linspace(0.8, 0.99, 20)

entropy_threshold_list = np.linspace(0, 1.6, 17)

combination_list = []
prioritizedview_performance_list = []
num_escape_study_list = []
escape_study_list = []

escape_study_viewpredictions_list = []
escape_study_diagnosispredictions_list = []
escape_study_diagnosistruelabels_list = []
escape_study_viewrelevance_list = []
escape_study_viewentropy_list = []

for confidence_threshold in confidence_threshold_list:
    print('########################Current confidence threshold: {}################'.format(confidence_threshold))
    
    for entropy_threshold in entropy_threshold_list:
        combination_list.append((confidence_threshold, entropy_threshold))
        
        print('Current entropy threshold: {}'.format(entropy_threshold))
        
        # candidate_view_dirs = [i for i in os.listdir(candidate_view_rootdir) if '.ipynb_checkpoints' not in i]

        for candidate_view in candidate_view_dirs:
        #     candidate_view = os.path.join(candidate_view_rootdir, candidate_view, 'best_predictions_at_ema_val')
            candidate_view = os.path.join(candidate_view, 'ForPatientTestSet_predictions')

#             if not os.path.exists(os.path.join(candidate_view, 'ForPatientTestSet_val_predictions.pkl')):
#                 continue
            View_predictions = load_pickle(candidate_view, 'ForPatientTestSet_val_predictions.pkl')

            for candidate_diagnosis in candidate_diagnosis_dirs:

                Diagnosis_predictions = load_pickle(candidate_diagnosis, 'val_predictions.pkl')

                #perform integration
                Diagnosis_true_labels = Diagnosis_predictions['true_labels']
                View_true_labels = View_predictions['true_labels']

                Diagnosis_predictions_values = Diagnosis_predictions['ema_predictions']
        #         Diagnosis_predictions_values = softmax(Diagnosis_predictions_values, axis=1)

                View_predictions_values = View_predictions['ema_predictions']
                View_predictions_values = softmax(View_predictions_values, axis=1)

                
                ConfidencedBased_PrioritizedView_predicted_labels = []
                ConfidencedBased_PrioritizedView_predictions = []

                study_true_diagnosis_labels = []

                escape_study_count = 0
                escape_studies = []
                
                escape_viewpredictions = []
                escape_diagnosispredictions = []
                escape_diagnosistruelabels = []
                escape_viewrelevance = []
                escape_viewentropy = []
                
                
                for idx, study in enumerate(Simplified_study_order_list):
        #             print('Currently aggregating predictions for {}'.format(study).center(100, '-'))
                    this_study_data_indices = list(range(Simplified_study_DataIndicesRange_list[idx][0], Simplified_study_DataIndicesRange_list[idx][1]))


                    this_study_diagnosis_predictions = Diagnosis_predictions_values[this_study_data_indices]
                    this_study_view_predictions = View_predictions_values[this_study_data_indices]
                    this_study_view_true_labels = View_true_labels[this_study_data_indices]

                    this_study_ViewRelevance =  np.sum(this_study_view_predictions[:,:2], axis=1)
                    this_study_ViewEntropy = entropy(this_study_view_predictions, axis=1)

                    #experiment with confidence level
                    confidence_mask = this_study_ViewRelevance >= confidence_threshold
                    
                    entropy_mask = this_study_ViewEntropy <= entropy_threshold
                    
                    final_mask = np.logical_and(confidence_mask, entropy_mask)
                    if np.sum(final_mask)<=0:
                        
                        escape_study_count+=1
                        escape_studies.append(study)
                        
                        this_study_diagnosis_true_labels = Diagnosis_true_labels[this_study_data_indices]
                        assert len(list(set(this_study_diagnosis_true_labels))) == 1, '1 study can only have 1 diagnosis label'
                        this_study_diagnosis_single_label = this_study_diagnosis_true_labels[0]
                        study_true_diagnosis_labels.append(this_study_diagnosis_single_label)

                        escape_viewpredictions.append(this_study_view_predictions)
                        escape_diagnosispredictions.append(this_study_diagnosis_predictions)
                        escape_diagnosistruelabels.append(this_study_diagnosis_single_label)
                        escape_viewrelevance.append(this_study_ViewRelevance)
                        escape_viewentropy.append(this_study_ViewEntropy)
                    

            #                 print('this_study_diagnosis_predictions: {}'.format(this_study_diagnosis_predictions.shape))
            #                 print('this_study_view_predictions: {}'.format(this_study_view_predictions.shape))

                        #Fall back to SimpleAveraging:
                        this_study_SimpleAveraging_prediction = np.mean(this_study_diagnosis_predictions, axis = 0) #a 1x3 vector
            #                 print('this_study_SimpleAveraging_prediction: {}'.format(this_study_SimpleAveraging_prediction))
                        this_study_SimpleAveraging_predicted_label = np.argmax(this_study_SimpleAveraging_prediction)
            #                 print('true_diagnosis:{}, SimpleAverage predicted_diagnosis:{}\n'.format(this_study_diagnosis_single_label, this_study_SimpleAveraging_predicted_label))

            
                        #record this patient's ConfidenceBased_PrioritizedView predictions and predicted labels
                        ConfidencedBased_PrioritizedView_predictions.append(this_study_SimpleAveraging_prediction)
                        ConfidencedBased_PrioritizedView_predicted_labels.append(this_study_SimpleAveraging_predicted_label)
            #                 print('true_diagnosis:{}, ConfidenceBased_PrioritizedView predicted_diagnosis:{}\n'.format(this_study_diagnosis_single_label, this_study_DiagnosisPredictedLabel_with_ViewRelevance))

                        continue
                    
#                     print('num images above confidence level: {}'.format(np.sum(confidence_mask)))
#                     print('num images below entropy level: {}'.format(np.sum(entropy_mask)))


                    this_study_diagnosis_true_labels = Diagnosis_true_labels[this_study_data_indices]
                    assert len(list(set(this_study_diagnosis_true_labels))) == 1, '1 study can only have 1 diagnosis label'
                    this_study_diagnosis_single_label = this_study_diagnosis_true_labels[0]
                    study_true_diagnosis_labels.append(this_study_diagnosis_single_label)


                #     print('this_study_diagnosis_predictions * this_study_ViewRelevance[:, np.newaxis] shape:{}'.format((this_study_diagnosis_predictions * this_study_ViewRelevance[:, np.newaxis]).shape))
                    this_study_DiagnosisPrediction_with_ViewRelevance = this_study_diagnosis_predictions * this_study_ViewRelevance[:, np.newaxis]
                    this_study_DiagnosisPrediction_with_ViewRelevance = this_study_DiagnosisPrediction_with_ViewRelevance[final_mask]
                    this_study_DiagnosisPrediction_with_ViewRelevance = np.mean(this_study_DiagnosisPrediction_with_ViewRelevance, axis=0)
        #                 print('this_study_DiagnosisPrediction_with_ViewRelevance: {}'.format(this_study_DiagnosisPrediction_with_ViewRelevance))


                    this_study_DiagnosisPredictedLabel_with_ViewRelevance = np.argmax(this_study_DiagnosisPrediction_with_ViewRelevance)

                    #record this patient's ConfidenceBased_PrioritizedView predictions and predicted labels
                    ConfidencedBased_PrioritizedView_predictions.append(this_study_DiagnosisPrediction_with_ViewRelevance)
                    ConfidencedBased_PrioritizedView_predicted_labels.append(this_study_DiagnosisPredictedLabel_with_ViewRelevance)
        #                 print('true_diagnosis:{}, ConfidenceBased_PrioritizedView predicted_diagnosis:{}\n'.format(this_study_diagnosis_single_label, this_study_DiagnosisPredictedLabel_with_ViewRelevance))
                
                num_escape_study_list.append(escape_study_count)
                escape_study_list.append(escape_studies)
                
                escape_study_viewpredictions_list.append(escape_viewpredictions)
                escape_study_diagnosispredictions_list.append(escape_diagnosispredictions)
                escape_study_diagnosistruelabels_list.append(escape_diagnosistruelabels)
                escape_study_viewrelevance_list.append(escape_viewrelevance)
                escape_study_viewentropy_list.append(escape_viewentropy)
                
                ConfidencedBased_PrioritizedView_predictions = np.array(ConfidencedBased_PrioritizedView_predictions)

        #                 print('\n\n')
                ConfidenceBased_PrioritizedView_balanced_accuracy = calculate_balanced_accuracy(study_true_diagnosis_labels, ConfidencedBased_PrioritizedView_predicted_labels)
#                 print('view: {}, diagnosis: {}'.format(candidate_view, candidate_diagnosis))
                print('ConfidenceBased_PrioritizedView_balanced_accuracy: {}\n\n'.format(ConfidenceBased_PrioritizedView_balanced_accuracy))
                
                prioritizedview_performance_list.append(ConfidenceBased_PrioritizedView_balanced_accuracy)
                
        
                
combination_list = np.array(combination_list)
prioritizedview_performance_list = np.array(prioritizedview_performance_list)
num_escape_study_list = np.array(num_escape_study_list)
escape_study_list = np.array(escape_study_list)
escape_study_viewpredictions_list = np.array(escape_study_viewpredictions_list)
escape_study_diagnosispredictions_list = np.array(escape_study_diagnosispredictions_list)
escape_study_diagnosistruelabels_list = np.array(escape_study_diagnosistruelabels_list)
escape_study_viewrelevance_list = np.array(escape_study_viewrelevance_list)
escape_study_viewentropy_list = np.array(escape_study_viewentropy_list)
# Out:
# ########################Current confidence threshold: 0.8################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.81################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.8200000000000001################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.8300000000000001################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.8400000000000001################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.85################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.86################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.87################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.88################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.89################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.9################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.287581699346404
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.73202614379085
#
#
# ########################Current confidence threshold: 0.91################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.732026143790854
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# ########################Current confidence threshold: 0.92################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.732026143790854
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.1764705882353
#
#
# ########################Current confidence threshold: 0.9299999999999999################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.732026143790854
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.732026143790854
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.95424836601306
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 58.62091503267973
#
#
# ########################Current confidence threshold: 0.94################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.732026143790854
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.732026143790854
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 59.39869281045751
#
#
# ########################Current confidence threshold: 0.95################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# ########################Current confidence threshold: 0.96################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 61.50980392156862
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 60.1764705882353
#
#
# ########################Current confidence threshold: 0.97################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# ########################Current confidence threshold: 0.98################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.52287581699345
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.22875816993464
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 62.49019607843137
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 63.47058823529411
#
#
# ########################Current confidence threshold: 0.99################
# Current entropy threshold: 0.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 36.143790849673195
#
#
# Current entropy threshold: 0.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 66.50326797385621
#
#
# Current entropy threshold: 0.2
# ConfidenceBased_PrioritizedView_balanced_accuracy: 67.74509803921569
#
#
# Current entropy threshold: 0.30000000000000004
# ConfidenceBased_PrioritizedView_balanced_accuracy: 66.41176470588235
#
#
# Current entropy threshold: 0.4
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.43137254901961
#
#
# Current entropy threshold: 0.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.43137254901961
#
#
# Current entropy threshold: 0.6000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 65.43137254901961
#
#
# Current entropy threshold: 0.7000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
#
#
# Current entropy threshold: 0.8
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
#
#
# Current entropy threshold: 0.9
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
#
#
# Current entropy threshold: 1.0
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
#
#
# Current entropy threshold: 1.1
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
#
#
# Current entropy threshold: 1.2000000000000002
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
#
#
# Current entropy threshold: 1.3
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
#
#
# Current entropy threshold: 1.4000000000000001
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
#
#
# Current entropy threshold: 1.5
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
#
#
# Current entropy threshold: 1.6
# ConfidenceBased_PrioritizedView_balanced_accuracy: 64.87581699346406
# <ipython-input-16-c1e6eec45faf>:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_list = np.array(escape_study_list)
# <ipython-input-16-c1e6eec45faf>:164: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_viewpredictions_list = np.array(escape_study_viewpredictions_list)
# <ipython-input-16-c1e6eec45faf>:165: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_diagnosispredictions_list = np.array(escape_study_diagnosispredictions_list)
# <ipython-input-16-c1e6eec45faf>:166: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_diagnosistruelabels_list = np.array(escape_study_diagnosistruelabels_list)
# <ipython-input-16-c1e6eec45faf>:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_viewrelevance_list = np.array(escape_study_viewrelevance_list)
# <ipython-input-16-c1e6eec45faf>:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   escape_study_viewentropy_list = np.array(escape_study_viewentropy_list)

# %%
np.argmax(prioritizedview_performance_list)
# Out:
# 325

# %%
##get all the occurance of the max value indices
max_all_indices = np.argwhere(prioritizedview_performance_list == np.max(prioritizedview_performance_list)).flatten().tolist()

# %%
max_all_indices
# Out:
# [325]

# %%
prioritizedview_performance_list[max_all_indices]
# Out:
# array([67.74509804])

# %%
num_escape_study_list[max_all_indices]
# Out:
# array([1])

# %%
escape_study_list[max_all_indices]
# Out:
# array([list(['1720159'])], dtype=object)

# %%
combination_list[max_all_indices]
# Out:
# array([[0.99, 0.2 ]])
